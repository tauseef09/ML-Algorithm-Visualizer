# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import os

# %% [markdown]
# # Regression

# %% [markdown]
# ### 1. Linear

# %%
df1 = pd.read_csv(os.path.join("..", "datasets", "regression_linear_line.csv"))

# %%
df1.head()
# Out:
#           x         y
# 0 -6.000000  5.766936
# 1 -5.967419  5.384906
# 2 -5.934837  5.344283
# 3 -5.902256  5.486492
# 4 -5.869674  5.196149

# %%
sns.scatterplot(x="x", y="y", data=df1)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# ### 2. Square Root

# %%
df2 = pd.read_csv(os.path.join("..", "datasets", "regression_linear_square_root.csv"))

# %%
df2.head()
# Out:
#           x         y
# 0 -6.000000  5.762776
# 1 -5.967419  5.063231
# 2 -5.934837  5.222449
# 3 -5.902256  6.024181
# 4 -5.869674  6.825703

# %%
sns.scatterplot(x="x", y="y", data=df2)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>

# %% [markdown]
# # Classification

# %% [markdown]
# ### 3. Linear Separable - Uniform

# %%
df3 = pd.read_csv(os.path.join("..", "datasets", "classification_linear_uniform.csv"))

# %%
df3.loc[ df3["y"] == -1, "y"] = 0
df3.head()
# Out:
#          x1        x2  y
# 0  0.299134  2.291594  1
# 1  0.700495  0.421917  1
# 2  3.114521  3.489704  1
# 3  2.671060  1.629899  1
# 4  3.035790  1.318322  1

# %%
sns.scatterplot(x="x1", y="x2", hue="y", data=df3)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %% [markdown]
# ### 4. Non-linear (XOR)

# %%
df4 = pd.read_csv(os.path.join("..", "datasets", "classification_nonlinear_xor.csv"))

# %%
df4.loc[ df4["y"] == -1, "y"] = 0
df4.head()
# Out:
#          x1        x2  y
# 0  2.415993  4.922784  1
# 1  4.489238  3.196620  1
# 2  4.935055  3.699012  1
# 3  1.589000  2.737612  1
# 4  2.112737  1.538858  1

# %%
sns.scatterplot(x="x1", y="x2", hue="y", data=df4)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %% [markdown]
# ### 5. Circular

# %%
df5 = pd.read_csv(os.path.join("..", "datasets", "classification_circle.csv"))

# %%
df5.loc[ df5["y"] == -1, "y"] = 0
df5.head()
# Out:
#          x1        x2  y
# 0  0.385697  1.235308  1
# 1  0.528159 -1.781597  1
# 2  0.935817 -1.414600  1
# 3  0.232862  0.822633  1
# 4  0.190594 -1.656273  1

# %%
sns.scatterplot(x="x1", y="x2", hue="y", data=df5)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %% [markdown]
# ### 6. Dependent Features

# %%
df6 = pd.read_csv(os.path.join("..", "datasets", "classification_dependent_feature.csv"))

# %%
df6.loc[ df6["y"] == -1, "y"] = 0
df6.head()
# Out:
#          x1         x2  y
# 0 -4.221546  17.821449  1
# 1 -5.444781  29.645640  1
# 2 -1.597306   2.551388  1
# 3 -1.576901   2.486618  1
# 4 -1.625671   2.642807  1

# %%
sns.scatterplot(x="x1", y="x2", hue="y", data=df6)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %% [markdown]
# ### 7. Independent Features

# %%
df7 = pd.read_csv(os.path.join("..", "datasets", "classification_naive_bayes_bernoulli_independent.csv"))

# %%
df7.head()
# Out:
#          x1        x2  y
# 0  0.071472 -1.328822  0
# 1 -0.460676 -0.217974  0
# 2 -1.474365 -1.406289  0
# 3 -1.650939  0.934005  0
# 4 -1.043427 -0.319130  0

# %%
sns.scatterplot(x="x1", y="x2", hue="y", data=df7)
# Out:
# <AxesSubplot:xlabel='x1', ylabel='x2'>

# %% [markdown]
# ### 8. Clustering with Outliers

# %%
df8 = pd.read_csv(os.path.join("..", "datasets", "classification_clustering_outliers.csv"))

# %%
df8.head()
# Out:
#           x         y
# 0 -3.166461  1.919370
# 1 -3.965074  1.173233
# 2 -3.366922  1.003308
# 3 -4.755280  0.708071
# 4 -4.970040  0.708572

# %%
sns.scatterplot(x="x", y="y", data=df8)
# Out:
# <AxesSubplot:xlabel='x', ylabel='y'>
